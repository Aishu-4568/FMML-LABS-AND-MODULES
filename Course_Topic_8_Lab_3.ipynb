# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishu-4568/FMML-LABS-AND-MODULES/blob/main/Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 15:58:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  72.9MB/s    in 0.9s
#
# 2024-03-30 15:58:12 (72.9 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10260   1005.0063v2  As increasing amounts of sensitive personal in...  stat
# 11050   1312.4479v1  Multivariate count data are defined as the num...  stat
# 31818   1009.3240v2  We study three families of online convex optim...    cs
# 22886  1710.01494v1  Deep convolutional neural networks (CNNs) base...  stat
# 2464   1503.08363v1  We consider the problem of learning convex agg...  stat
# ...             ...                                                ...   ...
# 22663  1703.09631v1  We consider a generalization of low-rank matri...  stat
# 23972  1505.00066v2  We address the task of predicting pose for obj...    cs
# 18612   1106.1817v1  Spoken dialogue systems promise efficient and ...    cs
# 10046  1611.08666v1  Training robots to perceive, act and communica...    cs
# 6731   1705.08821v2  Learning individual-level causal effects from ...  stat
#
#                                                    title  year  \
# 10260  Large Margin Multiclass Gaussian Classificatio...  2010
# 11050  Parametric Modelling of Multivariate Count Dat...  2013
# 31818  A Unified View of Regularized Dual Averaging a...  2010
# 22886  Strengths and Weaknesses of Deep Learning Mode...  2017
# 2464   Active Model Aggregation via Stochastic Mirror...  2015
# ...                                                  ...   ...
# 22663  Algebraic Variety Models for High-Rank Matrix ...  2017
# 23972         Pose Induction for Novel Object Categories  2015
# 18612  Automatically Training a Problematic Dialogue ...  2011
# 10046  Training an Interactive Humanoid Robot Using M...  2016
# 6731   Causal Effect Inference with Deep Latent-Varia...  2017
#
#                                                 keywords
# 10260  [increasing, sensitive, information, aggregate...
# 11050  [multivariate, different, categories, populati...
# 31818  [optimization, algorithms, proximally, regular...
# 22886  [convolutional, approaches, including, recogni...
# 2464   [aggregation, aggregation, classification, cur...
# ...                                                  ...
# 22663  [generalization, completion, algebraic, polyno...
# 23972  [predicting, unannotated, categories, annotate...
# 18612  [efficient, information, deficient, strategies...
# 10046  [communicate, modalities, represents, challeng...
# 6731   [individual, observational, inferring, effecti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10260    [increasing, sensitive, information, aggregate...
# 11050    [multivariate, different, categories, populati...
# 31818    [optimization, algorithms, proximally, regular...
# 22886    [convolutional, approaches, including, recogni...
# 2464     [aggregation, aggregation, classification, cur...
#                                ...
# 38452    [companies, collection, practices, difficult, ...
# 4037     [construct, extension, diffusion, modalities, ...
# 17874    [seemingly, acquisition, generated, cognitive,...
# 2758     [introduces, addresses, stochastic, correspond...
# 38270    [syntactic, parameters, languages, interaction...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8854 words.
# Out of those 4631 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="314c4300-59af-412b-ba69-fd6d15541bca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("314c4300-59af-412b-ba69-fd6d15541bca")) {                    Plotly.newPlot(                        "314c4300-59af-412b-ba69-fd6d15541bca",                        [{"x":["repositories","theoretical","revealing","introduced","classification","regularization","aggregated","individual","perturbation","increasing","discriminatively","perturbed","important","satisfies","differential","information","classifier","sensitive","processing","framework","development","instances","algorithm","mechanisms","multiclass","recurrent","particularly","simultaneously","consistent","independence","sociology","multivariate","distribution","individuals","categories","characterising","associated","different","identifying","specifically","population","econometrics","variables","modelling","graphical","parsimonious","covariates","conditional","probabilistic","represent","exclusive","relationships","parametric","partially","branching","logarithmic","contribution","optimization","algorithms","producing","regularized","demonstrate","particular","equivalence","cumulative","effective","composite","explicitly","observations","previously","experimental","subgradient","averaging","approximations","approximation","objective","outperforms","instantiations","strengths","potential","squeezenet","brightness","exploring","convolutional","architecture","currently","influence","occlusion","performance","experimentation","including","artifacts","characteristics","compression","considerable","techniques","descriptor","degradations","detrimental","approaches","architectures","significant","comprehensive","systematically","literature","weaknesses","relatively","investigate","recognition","googlenet","computation","improving","verification","stochastic","parameter","aggregation","aggregate","dependent","establish","significantly","incremental","applications","convexity","effectiveness","statistical","convergence","assumption","regression","estimation","restricted","applicability","phonological","considered","interpreted","converting","technology","interesting","characteristic","comparing","extraction","mathematics","correctly","presented","exceptional","acoustics","statistically","importance","parameters","comparative","difficulty","accurately","assessing","contextual","differences","surrounding","attention","readability","judgments","estimating","challenges","generated","predicting","introduce","intelligent","grammatical","conditions","aggregating","sentences","considering","guarantees","automatically","simulations","clustering","criterion","providing","computationally","iteratively","factorization","sufficient","hyperspectral","complexity","identifiability","structured","independently","computational","realistic","experiments","considers","sensitivity","understanding","practical","coefficient","decomposes","minimization","addressed","developed","suggested","dimension","iterative","quantitative"],"y":[6,155,6,132,504,87,17,114,14,108,4,5,370,14,22,710,143,56,279,594,108,114,842,53,11,148,101,115,88,25,2,21,208,38,62,1,112,776,64,163,54,0,128,51,44,5,2,102,151,120,4,65,55,49,6,23,66,335,588,29,44,540,270,24,16,240,21,77,73,105,398,3,28,47,122,157,261,6,25,155,1,4,35,384,260,53,58,38,879,20,248,20,101,41,41,399,27,4,2,442,125,246,63,23,140,18,63,141,379,9,138,98,25,147,114,18,18,70,43,272,32,431,13,204,151,107,56,121,192,57,42,4,147,27,15,59,72,28,61,117,15,26,190,5,3,30,90,233,40,48,59,13,51,61,20,175,5,13,75,111,170,78,328,61,10,139,12,67,74,72,183,45,131,48,94,103,39,36,69,8,237,3,125,42,313,60,584,33,32,154,139,28,7,58,41,191,24,50,73,77],"type":"bar"},{"x":["repositories","theo ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4631,), (4631, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7966666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Improving</span> <span style=''>Sparse</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.3892215568862275);'>Representations</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributional</span> <span style='background-color:rgba(255, 0, 0, 0.30225080385852093);'>Inference</span> <span style=''>for</span> <span style=''>Semantic</span> <span style='background-color:rgba(0, 255, 0, 0.43478260869565216);'>Composition</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Distributional</span> <span style=''>models</span> <span style=''>are</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>occurrences</span> <span style=''>in</span> <span style=''>a</span> <span style=''>corpus</span> <span style=''>where</span> <span style=''>only</span> <span style=''>a</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proportion</span> <span style=''>of</span> <span style=''>all</span> <span style=''>possible</span> <span style='background-color:rgba(0, 255, 0, 0.44);'>plausible</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>occurrences</span> <span style=''>will</span> <span style=''>be</span> <span style=''>observed</span> <span style=''>This</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>very</span> <span style=''>sparse</span> <span style=''>vector</span> <span style=''>space</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requiring</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.44047619047619047);'>mechanism</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>inferring</span> <span style=''>missing</span> <span style='background-color:rgba(0, 255, 0, 0.3715415019762846);'>knowledge</span> <span style=''>Most</span> <span style=''>methods</span> <span style=''>face</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>challenge</span> <span style=''>in</span> <span style=''>ways</span> <span style=''>that</span> <span style=''>render</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.3892215568862275);'>representations</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>uninterpretable</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequence</span> <span style=''>that</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.43478260869565216);'>composition</span> <span style=''>becomes</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>model</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>which</span> <span style=''>involves</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>inferring</span> <span style='background-color:rgba(255, 0, 0, 0.5999999999999999);'>unobserved</span> <span style=''>co</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>occurrences</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributional</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>neighbourhood</span> <span style=''>We</span> <span style=''>show</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Scalable</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>Using</span> <span style=''>Deep</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>It</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>querying</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>cheap</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>model</span> <span style=''>An</span> <span style=''>accurate</span> <span style=''>model</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>and</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>fit</span> <span style=''>using</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>(GPs)</span> <span style=''>However</span> <span style=''>since</span> <span style=''>GPs</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cubically</span> <span style=''>with</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>it</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>to</span> <span style=''>handle</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>requires</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluations</span> <span style=''>and</span> <span style=''>as</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>massively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parallelizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternati ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Inverse</span> <span style='background-color:rgba(0, 255, 0, 0.4207650273224044);'>Reinforcement</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Gaussian</span> <span style=''>Process</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>inverse</span> <span style='background-color:rgba(0, 255, 0, 0.4207650273224044);'>reinforcement</span> <span style=''>learning</span> <span style=''>(IRL</span> <span style=''>or</span> <span style=''>inverse</span> <span style=''>optimal</span> <span style=''>control)</span> <span style=''>in</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>settings</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>finite</span> <span style=''>space</span> <span style=''>IRL</span> <span style=''>can</span> <span style=''>be</span> <span style=''>posed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quadratic</span> <span style=''>program</span> <span style=''>under</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.30225080385852093);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>maximum</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6073059360730594);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>To</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>large</span> <span style=''>or</span> <span style=''>even</span> <span style=''>infinite</span> <span style=''>state</span> <span style=''>space</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>model</span> <span style=''>and</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preference</span> <span style=''>graphs</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3636363636363637);'>represent</span> <span style='background-color:rgba(255, 0, 0, 0.3482142857142857);'>observations</span> <span style=''>of</span> <span style=''>decision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>trajectories</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguished</span> <span style=''>from</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>IRL</span> <span style=''>in</span> <span style=''>that</span> <span style=''>it</span> <span style=''>makes</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3596059113300492);'>assumptions</span> <span style=''>about</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>the</span> <span style=''>reward</span> <span style=''>function</span> <span style=''>and</span> <span style=''>yet</span> <span style=''>it</span> <span style=''>retains</span> <span style=''>the</span> <span style=''>promise</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>manageable</span> <span style='background-color:rgba(0, 255, 0, 0.3114754098360655);'>implementation ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Predicting</span> <span style=''>Shot</span> <span style=''>Making</span> <span style=''>in</span> <span style=''>Basketball</span> <span style=''>Learnt</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Adversarial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiagent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Trajectories</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>predict</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>of</span> <span style=''>a</span> <span style=''>player</span> <span style=''>making</span> <span style=''>a</span> <span style=''>shot</span> <span style=''>in</span> <span style=''>basketball</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiagent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>Previous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>similar</span> <span style=''>problems</span> <span style=''>center</span> <span style=''>on</span> <span style=''>hand</span> <span style=''>crafting</span> <span style=''>features</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>domain</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>Although</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>prone</span> <span style=''>to</span> <span style=''>missing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>features</span> <span style=''>To</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>circumvent</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>(CNN)</span> <span style=''>approach</span> <span style=''>where</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represent</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiagent</span> <span style=''>behavior</span> <span style=''>as</span> <span style=''>an</span> <span style=''>image</span> <span style=''>To</span> <span style=''>encode</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>basketball</span> <span style=''>we</span> <span style=''>use</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>channel</span> <span style=''>image</span> <span style=''>which</span> <span style=''>we</span> <span style=''>then</span> <span style=''>feed</span> <span style=''>into</span> <span style=''>a</span> <span style=''>CNN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Additionally</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>temporal</span> <span style=''>aspect</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>we</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09476309226932668)
# 	representation (0.12896330602066264)
# 	architecture (0.09262557890986818)
# 	experimental (0.1417883861774136)
# 	information (0.25293908086925543)
# 	segmentation (0.0840755254720342)
# 	detection (0.1193444959030994)
# 	different (0.2764517278232989)
# 	convolutional (0.13680085500534378)
# 	recognition (0.1350195938724617)
#
# Some Statistics words are:
# 	distributions (0.12393376818866031)
# 	variables (0.13146011038635222)
# 	algorithm (0.38735574510787757)
# 	theoretical (0.14851981936778724)
# 	statistical (0.15102860010035124)
# 	estimation (0.16959357752132465)
# 	distribution (0.17962870045158053)
# 	dimensional (0.1921726041144004)
# 	inference (0.2032112393376819)
# 	regression (0.17812343201204214)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e0a24c11-656e-44bc-9cb9-daf8486da36a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0a24c11-656e-44bc-9cb9-daf8486da36a")) {                    Plotly.newPlot(                        "e0a24c11-656e-44bc-9cb9-daf8486da36a",                        [{"x":["repositories","theoretical","revealing","introduced","classification","regularization","aggregated","individual","perturbation","increasing","discriminatively","perturbed","important","satisfies","differential","information","classifier","sensitive","processing","framework","development","instances","algorithm","mechanisms","multiclass","recurrent","particularly","simultaneously","consistent","independence","sociology","multivariate","distribution","individuals","categories","characterising","associated","different","identifying","specifically","population","econometrics","variables","modelling","graphical","parsimonious","covariates","conditional","probabilistic","represent","exclusive","relationships","parametric","partially","branching","logarithmic","contribution","optimization","algorithms","producing","regularized","demonstrate","particular","equivalence","cumulative","effective","composite","explicitly","observations","previously","experimental","subgradient","averaging","approximations","approximation","objective","outperforms","instantiations","strengths","potential","squeezenet","brightness","exploring","convolutional","architecture","currently","influence","occlusion","performance","experimentation","including","artifacts","characteristics","compression","considerable","techniques","descriptor","degradations","detrimental","approaches","architectures","significant","comprehensive","systematically","literature","weaknesses","relatively","investigate","recognition","googlenet","computation","improving","verification","stochastic","parameter","aggregation","aggregate","dependent","establish","significantly","incremental","applications","convexity","effectiveness","statistical","convergence","assumption","regression","estimation","restricted","applicability","phonological","considered","interpreted","converting","technology","interesting","characteristic","comparing","extraction","mathematics","correctly","presented","exceptional","acoustics","statistically","importance","parameters","comparative","difficulty","accurately","assessing","contextual","differences","surrounding","attention","readability","judgments","estimating","challenges","generated","predicting","introduce","intelligent","grammatical","conditions","aggregating","sentences","considering","guarantees","automatically","simulations","clustering","criterion","providing","computationally","iteratively","factorization","sufficient","hyperspectral","complexity","identifiability","structured","independently","computational","realistic","experiments","considers","sensitivity","understanding","practical","coefficient","decomposes","minimization","addressed","developed","suggested","dimension","iterative","quantitative","embedding","comparison","reduction","incorporating","empirical","representation","therefore","challenge","determining","integrate","sentiment","syntactic","influences","performances","relatedness","benchmark","desirable","connections","fundamental","sequential","simulated","selection","stability","conducted","diversity","rearrange","inclusion","ensembles","selective","discovery","integration","generally","importantly","gradients","autoencoder","performed","calculation","multilayer","standardized","functions","perceptron","component","calculated","prediction","inherently","representations","similarity","integrating","multimodal","associative","embeddings","plausible","implicitly","exhibiti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	econometrics
# 	transmitting
# 	datapoint
# 	hamiltonian
# 	unweighted
# 	attraction
# 	trilinear
# 	factoring
# 	subproblem
# 	administrative
# 	jackknife
# 	infinitesimal
# 	metabolic
# 	roadworks
# 	maneuvering
# 	minimiser
# 	multinomial
# 	blockmodel
# 	unavoidably
# 	rightarrow
# Some words which never appear in Statistics papers:
# 	phonological
# 	acoustics
# 	readability
# 	grammatical
# 	cooperative
# 	inheritance
# 	dialogues
# 	perceptually
# 	intensify
# 	reflection
# 	objectness
# 	foregroundbackground
# 	indefinitely
# 	paraphrase
# 	deblurring
# 	misbehavior
# 	collaborating
# 	subtracting
# 	unification
# 	redistribution

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.058010458395768e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7466666666666667
